# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.cluster import KMeans

# %%
#load
data=pd.read_csv('customer_data_records.csv')

# %%
data.columns
# Out:
# Index(['CustomerID', 'Annual Income (k$)', 'Spending Score (1-100)'], dtype='object')

# %%
x=data[['Annual Income (k$)','Spending Score (1-100)']]

# %%
#clustering
kmeans=KMeans(n_clusters=2,random_state=0)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
data['cluster']=kmeans.labels_
print(data)
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)  cluster
# 0             1                 117                      20        1
# 1             2                 107                      59        1
# 2             3                  29                      36        0
# 3             4                 121                      19        1
# 4             5                  86                      90        0
# ..          ...                 ...                     ...      ...
# 169         170                 111                      76        1
# 170         171                 138                      87        1
# 171         172                  84                      15        0
# 172         173                 107                      92        1
# 173         174                  17                      98        0
#
# [174 rows x 4 columns]

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=data,y='Annual Income (k$)',x='Spending Score (1-100)',hue='cluster')
plt.title('Income vs spending')
plt.ylabel('Annual Income (k$)')
plt.xlabel('Spending Score (1-100)')
plt.show()

# %%
data.columns
# Out:
# Index(['CustomerID', 'Annual Income (k$)', 'Spending Score (1-100)',
#        'cluster'],
#       dtype='object')

# %%
#how customers earn
y=data[['CustomerID','Annual Income (k$)']]
kmeans.fit(y)
data['cluster']=kmeans.labels_

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=data,y='Annual Income (k$)',x='CustomerID',hue='cluster')
plt.title('customer income')
plt.ylabel('Annual Income (k$)')
plt.xlabel('CustomerID')
plt.show()

# %%
#how customers spend
a=data[['CustomerID','Spending Score (1-100)']]
kmeans.fit(a)
data['cluster']=kmeans.labels_

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=data,y='Spending Score (1-100)',x='CustomerID',hue='cluster')
plt.title('Customer spending')
plt.ylabel('Spending Score (1-100)')
plt.xlabel('CustomerID')
plt.show()
